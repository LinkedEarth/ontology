# %%
import re
import json

from pandas import DataFrame

from rdflib.graph import Graph
from rdflib.plugins.sparql.processor import SPARQLResult

# %%
def sparql_results_to_df(results: SPARQLResult) -> DataFrame:
    """
    Export results from an rdflib SPARQL query into a `pandas.DataFrame`,
    using Python types. See https://github.com/RDFLib/rdflib/issues/1179.
    """
    return DataFrame(
        data=([None if x is None else x.toPython() for x in row] for row in results),
        columns=[str(x) for x in results.vars],
    )

# %%
OUTPUT_FILE = "synonyms.json"
synonym_files = [
    {"variable": "ARCHIVES", "in":["archive.ttl"]},
    {"variable": "INTERPRETATION", "in":["interpretation.ttl"]},    
    {"variable": "PROXIES", "in":["paleo_proxy.ttl", "chron_proxy.ttl"]},
    {"variable": "UNITS", "in":["paleo_units.ttl", "chron_units.ttl"]},
    {"variable": "VARIABLES", "in":["paleo_variable.ttl", "chron_variable.ttl"]}
]

data = {}

for synonym_file in synonym_files:
    ttl_files = synonym_file["in"]
    var_name = synonym_file["variable"]

    syn_data = {}
    for ttl_file in ttl_files:
        graph = Graph()
        graph.parse(ttl_file)

        result = graph.query("""
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

        SELECT ?id ?type ?label ?noaa (GROUP_CONCAT(?syn;separator=" | ") as ?synonyms) WHERE {
            # ?id rdfs:label ?label .
            # ?id a ?type .
            FILTER( STRSTARTS(STR(?type),str(:))) .
            OPTIONAL { ?id :hasNoaaPastName ?noaa }
            OPTIONAL { ?id :hasSynonym ?syn }
        }
        GROUP BY ?id
        """)

        df = sparql_results_to_df(result)
        display(df)

        tmp = df.to_dict(orient="records")
        for line in tmp:
            label = line["label"]
            noaa = line["noaa"]
            id = line["id"]

            # Get the type
            type = re.sub("^.*#", "", line["type"])            
            if type not in syn_data:
                syn_data[type] = {}
            
            # Get the localname
            localname = re.sub("^.*#", "", id)

            # Add synonyms  
            line["synonyms"] = re.split("\s*\|\s*", line["synonyms"])
            line["synonyms"].insert(0, label.lower()) # Label is also a synonym
            line["synonyms"].insert(1, localname.lower()) # Localname is also a synonym
            if noaa:
                line["synonyms"].insert(2, noaa.lower()) # NOAA past name is also a synonym
            
            for syn in line["synonyms"]:
                if syn:
                    syn_data[type][syn.lower()] = {
                        "id": id,
                        "label": label
                    }
    
    data[var_name] = syn_data

with open(OUTPUT_FILE, "w") as ofile:
    json.dump(data, ofile, indent=3)
# Out:
#                                                    id  \
# 0       http://linked.earth/ontology/archive#Borehole
# 1          http://linked.earth/ontology/archive#Coral
# 2   http://linked.earth/ontology/archive#FluvialSe...
# 3     http://linked.earth/ontology/archive#GlacierIce
# 4      http://linked.earth/ontology/archive#GroundIce
# 5   http://linked.earth/ontology/archive#LakeSediment
# 6   http://linked.earth/ontology/archive#MarineSed...
# 7         http://linked.earth/ontology/archive#Midden
# 8   http://linked.earth/ontology/archive#MolluskShell
# 9           http://linked.earth/ontology/archive#Peat
# 10  http://linked.earth/ontology/archive#Sclerosponge
# 11     http://linked.earth/ontology/archive#Shoreline
# 12    http://linked.earth/ontology/archive#Speleothem
# 13  http://linked.earth/ontology/archive#Terrestri...
# 14          http://linked.earth/ontology/archive#Wood
# 15     http://linked.earth/ontology/archive#Documents
# 16         http://linked.earth/ontology/archive#Other
#
#                                                 type                 label  \
# 0   http://linked.earth/ontology/archive#ArchiveType              Borehole
# 1   http://linked.earth/ontology/archive#ArchiveType                 Coral
# 2   http://linked.earth/ontology/archive#ArchiveType      Fluvial sediment
# 3   http://linked.earth/ontology/archive#ArchiveType           Glacier ice
# 4   http://linked.earth/ontology/archive#ArchiveType            Ground ice
# 5   http://linked.earth/ontology/archive#ArchiveType         Lake sediment
# 6   http://linked.earth/ontology/archive#ArchiveType       Marine sediment
# 7   http://linked.earth/ontology/archive#ArchiveType                Midden
# 8   http://linked.earth/ontology/archive#ArchiveType         Mollusk shell
# 9   http://linked.earth/ontology/archive#ArchiveType                  Peat
# 10  http://linked.earth/ontology/archive#ArchiveType          Sclerosponge
# 11  http://linked.earth/ontology/archive#ArchiveType             Shoreline
# 12  http://linked.earth/ontology/archive#ArchiveType            Speleothem
# 13  http://linked.earth/ontology/archive#ArchiveType  Terrestrial sediment
# 14  http://linked.earth/ontology/archive#ArchiveType                  Wood
# 15  http://linked.earth/ontology/archive#ArchiveType             Documents
# 16  http://linked.earth/ontology/archive#ArchiveType                 Other
#
#             noaa                          synonyms
# 0       borehole
# 1          coral
# 2           None  Creek | Fluvial | River | Stream
# 3      ice cores
# 4       bulk ice
# 5           None     Lagoon | Lake | Lake Sediment
# 6           None                    Delta | Marine
# 7           None
# 8        bivalve                     MolluskShells
# 9           peat  Bog | Fen | Marsh | Mire | Swamp
# 10  sclerosponge
# 11   lake levels        LakeDeposit | LakeDeposits
# 12   speleothems                              Cave
# 13          None                      Dune | Loess
# 14     tree ring                              tree
# 15     documents
# 16         other
#                                                     id  \
# 0    http://linked.earth/ontology/interpretation#C3...
# 1    http://linked.earth/ontology/interpretation#ci...
# 2    http://linked.earth/ontology/interpretation#ci...
# 3    http://linked.earth/ontology/interpretation#di...
# 4     http://linked.earth/ontology/interpretation#dust
# ..                                                 ...
# 172  http://linked.earth/ontology/interpretation#Su...
# 173  http://linked.earth/ontology/interpretation#Wa...
# 174  http://linked.earth/ontology/interpretation#We...
# 175  http://linked.earth/ontology/interpretation#Wi...
# 176  http://linked.earth/ontology/interpretation#Wi...
#
#                                                   type                label  \
# 0    http://linked.earth/ontology/interpretation#In...            C3C4Ratio
# 1    http://linked.earth/ontology/interpretation#In...     circulationIndex
# 2    http://linked.earth/ontology/interpretation#In...  circulationVariable
# 3    http://linked.earth/ontology/interpretation#In...      dissolvedOxygen
# 4    http://linked.earth/ontology/interpretation#In...                 dust
# ..                                                 ...                  ...
# 172  http://linked.earth/ontology/interpretation#In...               Summer
# 173  http://linked.earth/ontology/interpretation#In...        Warmest Month
# 174  http://linked.earth/ontology/interpretation#In...           Wet Season
# 175  http://linked.earth/ontology/interpretation#In...              Win-Spr
# 176  http://linked.earth/ontology/interpretation#In...               Winter
#
#                      noaa                                           synonyms
# 0                    None                           composition C3-C4 plants
# 1       circulation index                                   MODE | NAO index
# 2    circulation variable  changes in monsoon intensity. | circulation | ...
# 3        dissolved oxygen                                            suboxia
# 4                    dust                                               DUST
# ..                    ...                                                ...
# 172                summer  summer | warm season | mostly summer | summer+...
# 173          231Pa excess                            warmest month | warmest
# 174                  None  monsoon | Andean wet season | Monsoon | monsoo...
# 175                  None                                      winter/spring
# 176                winter                   winter | winter+ | mostly winter
#
# [177 rows x 5 columns]
#                                                    id  \
# 0   http://linked.earth/ontology/proxy#accumulatio...
# 1              http://linked.earth/ontology/proxy#ACL
# 2            http://linked.earth/ontology/proxy#Al2O3
# 3         http://linked.earth/ontology/proxy#alkenone
# 4           http://linked.earth/ontology/proxy#amoeba
# ..                                                ...
# 89  http://linked.earth/ontology/proxy#floral_asse...
# 90        http://linked.earth/ontology/proxy#isotopic
# 91         http://linked.earth/ontology/proxy#mineral
# 92       http://linked.earth/ontology/proxy#pyrogenic
# 93   http://linked.earth/ontology/proxy#sedimentology
#
#                                                  type              label  \
# 0       http://linked.earth/ontology/proxy#PaleoProxy  accumulation rate
# 1       http://linked.earth/ontology/proxy#PaleoProxy                ACL
# 2       http://linked.earth/ontology/proxy#PaleoProxy              Al2O3
# 3       http://linked.earth/ontology/proxy#PaleoProxy           alkenone
# 4       http://linked.earth/ontology/proxy#PaleoProxy             amoeba
# ..                                                ...                ...
# 89  http://linked.earth/ontology/proxy#PaleoProxyG...  floral assemblage
# 90  http://linked.earth/ontology/proxy#PaleoProxyG...           isotopic
# 91  http://linked.earth/ontology/proxy#PaleoProxyG...            mineral
# 92  http://linked.earth/ontology/proxy#PaleoProxyG...          pyrogenic
# 93  http://linked.earth/ontology/proxy#PaleoProxyG...      sedimentology
#
#                     noaa          synonyms
# 0                   None  sed accumulation
# 1   average chain length
# 2         aluminum oxide
# 3               alkenone
# 4         testate amoeba
# ..                   ...               ...
# 89                  None
# 90               isotope
# 91                  None
# 92          fire history
# 93                  None
#
# [94 rows x 5 columns]
# Empty DataFrame
# Columns: [id, type, label, noaa, synonyms]
# Index: []
#                                                  id  \
# 0   http://linked.earth/ontology/units#atomic_ratio
# 1            http://linked.earth/ontology/units#cgs
# 2             http://linked.earth/ontology/units#cm
# 3         http://linked.earth/ontology/units#cm_kyr
# 4          http://linked.earth/ontology/units#cm_yr
# ..                                              ...
# 66         http://linked.earth/ontology/units#yr_AD
# 67        http://linked.earth/ontology/units#yr_b2k
# 68         http://linked.earth/ontology/units#yr_BP
# 69         http://linked.earth/ontology/units#yr_ka
# 70       http://linked.earth/ontology/units#z_score
#
#                                             type         label  \
# 0   http://linked.earth/ontology/units#PaleoUnit  atomic ratio
# 1   http://linked.earth/ontology/units#PaleoUnit           cgs
# 2   http://linked.earth/ontology/units#PaleoUnit            cm
# 3   http://linked.earth/ontology/units#PaleoUnit        cm/kyr
# 4   http://linked.earth/ontology/units#PaleoUnit         cm/yr
# ..                                           ...           ...
# 66  http://linked.earth/ontology/units#PaleoUnit         yr AD
# 67  http://linked.earth/ontology/units#PaleoUnit        yr b2k
# 68  http://linked.earth/ontology/units#PaleoUnit         yr BP
# 69  http://linked.earth/ontology/units#PaleoUnit         yr ka
# 70  http://linked.earth/ontology/units#PaleoUnit       z score
#
#                                 noaa  \
# 0                       atomic ratio
# 1         dimensionless (CGS system)
# 2                         centimeter
# 3            centimeter per kiloyear
# 4                centimeter per year
# ..                               ...
# 66                   year Common Era
# 67                              None
# 68      calendar year before present
# 69  calendar kiloyear before present
# 70           standard deviation unit
#
#                                              synonyms
# 0                                        Atomic ratio
# 1
# 2                                               cmblf
# 3
# 4                                      cm/a | cm yr-1
# ..                                                ...
# 66  yr | CE | AD | year ce | ad/bc | cal yr AD | y...
# 67              b2000 | cal. BP2000 | Years before 2k
# 68  BP | cal years BP | cal year BP | cal yr BP | ...
# 69                                                 ka
# 70              zscore | SD units | std dev | SD | sd
#
# [71 rows x 5 columns]
# Empty DataFrame
# Columns: [id, type, label, noaa, synonyms]
# Index: []
#                                                     id  \
# 0           http://linked.earth/ontology/variables#ACL
# 1       http://linked.earth/ontology/variables#AET_PET
# 2       http://linked.earth/ontology/variables#ARM_IRM
# 3        http://linked.earth/ontology/variables#ARSTAN
# 4            http://linked.earth/ontology/variables#Al
# ..                                                 ...
# 294  http://linked.earth/ontology/variables#waterCo...
# 295  http://linked.earth/ontology/variables#waterTa...
# 296  http://linked.earth/ontology/variables#wetBulk...
# 297        http://linked.earth/ontology/variables#year
# 298      http://linked.earth/ontology/variables#zscore
#
#                                                   type            label  \
# 0    http://linked.earth/ontology/variables#PaleoVa...              ACL
# 1    http://linked.earth/ontology/variables#PaleoVa...          AET/PET
# 2    http://linked.earth/ontology/variables#PaleoVa...          ARM/IRM
# 3    http://linked.earth/ontology/variables#PaleoVa...           ARSTAN
# 4    http://linked.earth/ontology/variables#PaleoVa...               Al
# ..                                                 ...              ...
# 294  http://linked.earth/ontology/variables#PaleoVa...     waterContent
# 295  http://linked.earth/ontology/variables#PaleoVa...  waterTableDepth
# 296  http://linked.earth/ontology/variables#PaleoVa...   wetBulkDensity
# 297  http://linked.earth/ontology/variables#PaleoVa...             year
# 298  http://linked.earth/ontology/variables#PaleoVa...           zscore
#
#                                                   noaa  \
# 0                                 average chain length
# 1                                                 None
# 2    anhysteretic remanent magnetization/isothermal...
# 3                             ARSTAN chronology method
# 4                                             aluminum
# ..                                                 ...
# 294                                      water content
# 295                                  water table depth
# 296                                               None
# 297                                               year
# 298                               collection elevation
#
#                                               synonyms
# 0    ACL (27-33) | ACL25-35 | ACL27-31 | ACLC22-30 ...
# 1
# 2                                              arm_irm
# 3                                                  ARS
# 4                                Al peak area | AlProp
# ..                                                 ...
# 294
# 295  Water Table | Water Table Detrended | Water_ta...
# 296                                              WetBD
# 297  Recon0x2EDate | Year | Year b2k | age_CE | yea...
# 298                                            Z_score
#
# [299 rows x 5 columns]
# Empty DataFrame
# Columns: [id, type, label, noaa, synonyms]
# Index: []
